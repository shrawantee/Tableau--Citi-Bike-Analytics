# %%
# Dependencies and Setup
import csv
import pandas as pd
import warnings

warnings.simplefilter("error")

# %%
file1_pd_16 = pd.read_csv("JC-201601-citibike-tripdata.csv")
file2_pd_16 = pd.read_csv("JC-201602-citibike-tripdata.csv")
file3_pd_16 = pd.read_csv("JC-201603-citibike-tripdata.csv")
file4_pd_16 = pd.read_csv("JC-201604-citibike-tripdata.csv")
file5_pd_16 = pd.read_csv("JC-201605-citibike-tripdata.csv")
file6_pd_16 = pd.read_csv("JC-201606-citibike-tripdata.csv")
file7_pd_16 = pd.read_csv("JC-201607-citibike-tripdata.csv")
file8_pd_16 = pd.read_csv("JC-201608-citibike-tripdata.csv")
file9_pd_16 = pd.read_csv("JC-201609-citibike-tripdata.csv")
file10_pd_16 = pd.read_csv("JC-201610-citibike-tripdata.csv")
file11_pd_16 = pd.read_csv("JC-201611-citibike-tripdata.csv")
file12_pd_16 = pd.read_csv("JC-201612-citibike-tripdata.csv")
#17
file1_pd_17 = pd.read_csv("JC-201701-citibike-tripdata.csv")
file2_pd_17 = pd.read_csv("JC-201702-citibike-tripdata.csv")
file3_pd_17 = pd.read_csv("JC-201703-citibike-tripdata.csv")
file4_pd_17 = pd.read_csv("JC-201704-citibike-tripdata.csv")
file5_pd_17 = pd.read_csv("JC-201705-citibike-tripdata.csv")
file6_pd_17 = pd.read_csv("JC-201706-citibike-tripdata.csv")
file7_pd_17 = pd.read_csv("JC-201707-citibike-tripdata.csv")
file8_pd_17 = pd.read_csv("JC-201708-citibike-tripdata.csv")
file9_pd_17 = pd.read_csv("JC-201709-citibike-tripdata.csv")
file10_pd_17 = pd.read_csv("JC-201710-citibike-tripdata.csv")
file11_pd_17 = pd.read_csv("JC-201711-citibike-tripdata.csv")
file12_pd_17 = pd.read_csv("JC-201712-citibike-tripdata.csv")
#18
file1_pd_18 = pd.read_csv("JC-201801-citibike-tripdata.csv")
file2_pd_18 = pd.read_csv("JC-201802-citibike-tripdata.csv")
file3_pd_18 = pd.read_csv("JC-201803-citibike-tripdata.csv")
file4_pd_18 = pd.read_csv("JC-201804-citibike-tripdata.csv")
file5_pd_18 = pd.read_csv("JC-201805-citibike-tripdata.csv")
file6_pd_18 = pd.read_csv("JC-201806-citibike-tripdata.csv")
file7_pd_18 = pd.read_csv("JC-201807-citibike-tripdata.csv")
file8_pd_18 = pd.read_csv("JC-201808-citibike-tripdata.csv")
file9_pd_18 = pd.read_csv("JC-201809-citibike-tripdata.csv")
file10_pd_18 = pd.read_csv("JC-201810-citibike-tripdata.csv")

# %%
citibike_tripdata_2016 = pd.concat([file1_pd_16, file2_pd_16, file3_pd_16,file4_pd_16,file5_pd_16, file6_pd_16, file7_pd_16,file8_pd_16,file9_pd_16, file10_pd_16, file11_pd_16,file12_pd_16],axis=0)

# %%
# # Script to merge several CSVs into one

# import glob
# import csv

# # Change delimiter to the appropriate one in CSV
# delimiter = ';'

# csvs = glob.glob('*.csv')

# f = open('merged_data.csv', 'wb')
# master_csv = csv.writer(f)

# # Take the header of the first CSV and make it the master header
# first_csv = open(csvs[0], 'rb')
# headers = first_csv.readline().strip().split(delimiter)
# master_csv.writerow(headers)
# # Write remaining rows
# for line in first_csv:
#     master_csv.writerow(line.strip().split(delimiter))

# # Read remaining CSVs and skip the first row
# for file in csvs[1:]:
#     current_csv = open(file, 'rb')
#     for line_num, line in enumerate(current_csv):
#         if line_num > 0:
#             master_csv.writerow(line.strip().split(delimiter))
            
# f.close()

# %%
citibike_tripdata_2016.isnull().any()
# Out:
# Trip Duration              False
# Start Time                 False
# Stop Time                  False
# Start Station ID           False
# Start Station Name         False
# Start Station Latitude     False
# Start Station Longitude    False
# End Station ID             False
# End Station Name           False
# End Station Latitude       False
# End Station Longitude      False
# Bike ID                    False
# User Type                   True
# Birth Year                  True
# Gender                     False
# dtype: bool

# %%
citibike_tripdata_2016.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# ...

# %%
citibike_tripdata_2016_clean = citibike_tripdata_2016.dropna(axis=0).reset_index(drop=True)
citibike_tripdata_2016_clean.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            445  2016-01-01 01:07:45  2016-01-01 01:15:11              3186
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4      Grove St PATH               40.719586               -74.043117
#
#    End Station ID End Station Name  End Station Latitude  \
# ...

# %%
citibike_tripdata_2016_clean["Birth Year"] = citibike_tripdata_2016_clean["Birth Year"].astype(int)

# %%
citibike_tripdata_2016_clean.dtypes
# Out:
# Trip Duration                int64
# Start Time                  object
# Stop Time                   object
# Start Station ID             int64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID               int64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                      int64
# User Type                   object
# Birth Year                   int64
# Gender                       int64
# dtype: object

# %%
citibike_tripdata_2016_clean.to_csv("CitibikeTripdata2016.csv", index=False)

# %%
citibike_tripdata_2017 = pd.concat([file1_pd_17, file2_pd_17, file3_pd_16,file4_pd_16,file5_pd_16, file6_pd_16, file7_pd_16,file8_pd_16,file9_pd_16, file10_pd_16, file11_pd_16,file12_pd_16],axis=0)

# %%
citibike_tripdata_2017.isnull().any()
# Out:
# Trip Duration              False
# Start Time                 False
# Stop Time                  False
# Start Station ID           False
# Start Station Name         False
# Start Station Latitude     False
# Start Station Longitude    False
# End Station ID             False
# End Station Name           False
# End Station Latitude       False
# End Station Longitude      False
# Bike ID                    False
# User Type                   True
# Birth Year                  True
# Gender                     False
# dtype: bool

# %%
citibike_tripdata_2017.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1           1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2            372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3           1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4            639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  \
# ...

# %%
citibike_tripdata_2017_clean = citibike_tripdata_2017.dropna(axis=0).reset_index(drop=True)
#citibike_tripdata_2017_clean.head()
citibike_tripdata_2017_clean["Birth Year"] = citibike_tripdata_2017_clean["Birth Year"].astype(int)
citibike_tripdata_2017_clean.dtypes
citibike_tripdata_2017_clean.to_csv("CitibikeTripdata2017.csv", index=False)

# %%
citibike_tripdata_2018 = pd.concat([file1_pd_18, file2_pd_18, file3_pd_18,file4_pd_18,file5_pd_18, file6_pd_18, file7_pd_18,file8_pd_18,file9_pd_18, file10_pd_18],axis=0)
# Out:
# ---------------------------------------------------------------------------
# FutureWarning                             Traceback (most recent call last)
# <ipython-input-23-34c3178558a5> in <module>()
# ----> 1 citibike_tripdata_2018 = pd.concat([file1_pd_18, file2_pd_18, file3_pd_18,file4_pd_18,file5_pd_18, file6_pd_18, file7_pd_18,file8_pd_18,file9_pd_18, file10_pd_18],axis=0)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ...

# %%
citibike_tripdata_2018.isnull().any()
citibike_tripdata_2018_clean = citibike_tripdata_2018.dropna(axis=0).reset_index(drop=True)

citibike_tripdata_2018_clean["Birth Year"] = citibike_tripdata_2018_clean["Birth Year"].astype(int)
citibike_tripdata_2018_clean.dtypes
citibike_tripdata_2018_clean.to_csv("CitibikeTripdata2018.csv", index=False)
